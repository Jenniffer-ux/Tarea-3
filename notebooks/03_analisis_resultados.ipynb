# %%
from IPython.display import Markdown

Markdown("""
## 🔎 Limitaciones
- No se usan GPUs ni frameworks optimizados
- No hay dropout, batchnorm, ni optimizadores como Adam

## 🚀 Escalabilidad con TensorFlow
- Aceleración GPU
- APIs para manejo de grandes volúmenes
- Entrenamiento distribuido

## 🗺️ Roadmap
- Añadir validación cruzada
- Migrar a Keras
- Conectar con datos reales
- Desplegar con FastAPI
""")
# Out:
# ## 🔎 Limitaciones
# - No se usan GPUs ni frameworks optimizados
# - No hay dropout, batchnorm, ni optimizadores como Adam
#
# ## 🚀 Escalabilidad con TensorFlow
# - Aceleración GPU
# - APIs para manejo de grandes volúmenes
# - Entrenamiento distribuido
#
# ## 🗺️ Roadmap
# - Añadir validación cruzada
# - Migrar a Keras
# - Conectar con datos reales
# - Desplegar con FastAPI
